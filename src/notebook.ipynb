# %%
import trainer
# Out:
# /home/justin/dev/anaconda3/lib/python3.11/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/justin/dev/anaconda3/lib/python3.11/site-packages/torchvision/image.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
asdf = trainer.trainer()
# Out:
# ==================== basic setting start ====================
# experiment_index    : None
# cudas               : 0
# num_workers         : 4
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# learning_rate       : 0.0001
# batch_size          : 12
# resume              :
# n_epochs            : 250
# eval_frequency      : 1
# seed                : 47
# eps                 : 1e-07
# weight_decay        : 0
# optimizer           : SGD
# backbone            : resnet50
# initialization      : pretrained
# server              : lab_center
# num_classes         : 7
# iter_fold           : 1
# nproc_per_node      : 4
# local_rank          : 0
# loss_fn             : WCE
# ==================== basic setting end ====================
# => Image resize to 300 and crop to 224
# => init_environment with seed: 47
# => Use cuda: 0
# > Use seed -47

# %%
asdf.train()
# Out:
# /home/justin/dev/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/justin/dev/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# => Using device ids: 0
# Model single cuda
# => self.iter_fold is 1
# Loss function is WCE
# => Using self.optimizer SGD with lr:0.0001
# Train from scrach!!
# OpenBLAS Warning : Detect OpenMP Loop and this application may hang. Please rebuild the library with USE_OPENMP=1 option.
# ...
